# %%
import csv

# %%
with open("bell_20180330_xyrev.csv", "r") as f:
    dat = list(csv.reader(f))[1:]

# %%
dat2 = [(x,y) for (x,y) in dat if float(x)%10==0]

# %%
dat2
# Out:
# [('0.0', '299.99999999999983'),
#  ('10.0', '219.84342153123205'),
#  ('20.0', '175.61495606623276'),
#  ('30.0', '147.30172055958914'),
#  ('40.0', '127.50051564398521'),
#  ('50.0', '112.81171712137102'),
#  ('60.0', '101.44627139038074'),
#  ('70.0', '92.3692681295495'),
#  ('80.0', '84.93875158642402'),
#  ('90.0', '78.73451587771187'),
#  ('100.0', '73.46949203793613'),
#  ('110.0', '68.94061335430317'),
#  ('120.0', '65.00001571896624'),
#  ('130.0', '61.537366600429486'),
#  ('140.0', '58.46859771815104'),
#  ('150.0', '55.72848178213484'),
#  ('160.0', '53.2656017651932'),
#  ('170.0', '51.03885662671294'),
#  ('180.0', '49.01498110031373'),
#  ('190.0', '47.16675112088241'),
#  ('200.0', '45.471662888359496'),
#  ('210.0', '43.91094546180362'),
#  ('220.0', '42.46881231846235'),
#  ('230.0', '41.13188682533884'),
#  ('240.0', '39.888756094589056'),
#  ('250.0', '38.729620853858805'),
#  ('260.0', '37.64601798557387'),
#  ('270.0', '36.6305986732072'),
# ...

# %%
with open("bell_20180330_p10.csv", "w", newline='') as out:
    writer = csv.writer(out)
    writer.writerows(dat2)
